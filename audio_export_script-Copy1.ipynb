# %%
from pydub import AudioSegment
from pydub.utils import make_chunks
import os

# %%
import os

from torch.utils.data import Dataset
import pandas as pd
import torchaudio
from torch import nn
import numpy as np
from pydub import AudioSegment
import torch
from torch.utils.data import DataLoader
import tensorflow as tf

import torch.nn.functional as F
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/torchaudio/backend/utils.py:53: UserWarning: "sox" backend is being deprecated. The default backend will be changed to "sox_io" backend in 0.8.0 and "sox" backend will be removed in 0.9.0. Please migrate to "sox_io" backend. Please refer to https://github.com/pytorch/audio/issues/903 for the detail.
#   warnings.warn(

# %%
ls
# Out:
# Anxiety Flute (1)/               Happy Sarod (2)/
# Anxiety Flute (2)/               SAD sitar (1)/
# Anxiety Sarod (1)/               Sad Flute (1)/
# Anxiety Sarod (2)/               Sad Flute (2)/
# Anxiety Sitar (1)/               Sad Sarod (1)/
# Anxiety Sitar (2)/               Sad Sarod (2)/
# Calm Flute (1)/                  __pycache__/
# Calm Sitar (2)/                  annotations.csv
# Calm flute (2)/                  audio_export_script-Copy1.ipynb
# Calm sarod (1)/                  audio_export_script.ipynb
# Calm sarod (2)/                  cnn.py
# Calm sitar (1)/                  feedforwardnet.pth
# HAPPY sitar (2)/                 happy sitar (1)/
# Happy Flute (1)/                 new_data/
# Happy Flute (2)/                 sad sitar (2)/
# Happy Sarod (1)/                 splice_try/

# %%
annotations=[]

# %%
counter=0

# %%
ph=0-1

objclass=0
for j in range(0,100):
    to_add="Anxiety Flute (1)/"+"A"+str(j+1)+".wav"

    pathway_part= ""
    pathway=os.path.join(pathway_part,to_add)

    myaudio = AudioSegment.from_file(pathway , "wav") 
    chunk_length_ms = 5000 # pydub calculates in millisec
    chunks = make_chunks(myaudio, chunk_length_ms) #Make chunks of five secs

    pathway_part= "splice_try"
    #pathway=os.path.join(pathway_part,to_add)


    ph=ph+1
    for i, chunk in enumerate(chunks):
        to_add2="A"+"F"+str(ph+i)+".wav"
        pl=os.path.join(pathway_part,to_add2)
        chunk_name = pl.format(i)
        if(len(chunk)==5000):  
            print("exporting", chunk_name)
            chunk.export(chunk_name, format="wav")
            annotations.append([pl, objclass])
            counter+=1
        else:
            i=i-1
    ph=ph+i
    objclass=0
    #annotations.append([pl, objclass])
    
    
    
    
    

for j in range(100,200):
    to_add="Anxiety Flute (2)/"+"A"+str(j+1)+".wav"

    pathway_part= ""
    pathway=os.path.join(pathway_part,to_add)

    myaudio = AudioSegment.from_file(pathway , "wav") 
    chunk_length_ms = 5000 # pydub calculates in millisec
    chunks = make_chunks(myaudio, chunk_length_ms) #Make chunks of five secs

    pathway_part= "splice_try"
    #pathway=os.path.join(pathway_part,to_add)


    ph=ph+1
    for i, chunk in enumerate(chunks):
        to_add2="A"+"F"+str(ph+i)+".wav"
        pl=os.path.join(pathway_part,to_add2)
        chunk_name = pl.format(i)
        if(len(chunk)==5000):  
            print("exporting", chunk_name)
            chunk.export(chunk_name, format="wav")
            annotations.append([pl, objclass])
            counter+=1
        else:
            i=i-1
    ph=ph+i
    
    
    
for j in range(0,100):
    to_add="Calm Flute (1)/"+"C"+str(j+1)+".wav"

    pathway_part= ""
    pathway=os.path.join(pathway_part,to_add)

    myaudio = AudioSegment.from_file(pathway , "wav") 
    chunk_length_ms = 5000 # pydub calculates in millisec
    chunks = make_chunks(myaudio, chunk_length_ms) #Make chunks of five secs

    pathway_part= "splice_try"
    #pathway=os.path.join(pathway_part,to_add)


    ph=ph+1
    for i, chunk in enumerate(chunks):
        to_add2="C"+"F"+str(ph+i)+".wav"
        pl=os.path.join(pathway_part,to_add2)
        chunk_name = pl.format(i)
        if(len(chunk)==5000):  
            print("exporting", chunk_name)
            chunk.export(chunk_name, format="wav")
            annotations.append([pl, objclass])
            counter+=1
        else:
            i=i-1
    ph=ph+i

    
    
    
    

for j in range(100,200):
    to_add="Calm flute (2)/"+"C"+str(j+1)+".wav"

    pathway_part= ""
    pathway=os.path.join(pathway_part,to_add)

    myaudio = AudioSegment.from_file(pathway , "wav") 
    chunk_length_ms = 5000 # pydub calculates in millisec
    chunks = make_chunks(myaudio, chunk_length_ms) #Make chunks of five secs

    pathway_part= "splice_try"
    #pathway=os.path.join(pathway_part,to_add)


    ph=ph+1
    for i, chunk in enumerate(chunks):
        to_add2="C"+"F"+str(ph+i)+".wav"
        pl=os.path.join(pathway_part,to_add2)
        chunk_name = pl.format(i)
        if(len(chunk)==5000):  
            print("exporting", chunk_name)
            chunk.export(chunk_name, format="wav")
            annotations.append([pl, objclass])
            counter+=1
        else:
            i=i-1
    ph=ph+i
   
 
    
    
    

for j in range(0,100):
    to_add="Happy Flute (1)/"+"H"+str(j+1)+".wav"

    pathway_part= ""
    pathway=os.path.join(pathway_part,to_add)

    myaudio = AudioSegment.from_file(pathway , "wav") 
    chunk_length_ms = 5000 # pydub calculates in millisec
    chunks = make_chunks(myaudio, chunk_length_ms) #Make chunks of five secs

    pathway_part= "splice_try"
    #pathway=os.path.join(pathway_part,to_add)


    ph=ph+1
    for i, chunk in enumerate(chunks):
        to_add2="H"+"F"+str(ph+i)+".wav"
        pl=os.path.join(pathway_part,to_add2)
        chunk_name = pl.format(i)
        if(len(chunk)==5000):  
            print("exporting", chunk_name)
            chunk.export(chunk_name, format="wav")
            annotations.append([pl, objclass])
            counter+=1
        else:
            i=i-1
    ph=ph+i

    
    
    
    

for j in range(100,200):
    to_add="Happy Flute (2)/"+"H"+str(j+1)+".wav"

    pathway_part= ""
    pathway=os.path.join(pathway_part,to_add)

    myaudio = AudioSegment.from_file(pathway , "wav") 
    chunk_length_ms = 5000 # pydub calculates in millisec
    chunks = make_chunks(myaudio, chunk_length_ms) #Make chunks of five secs

    pathway_part= "splice_try"
    #pathway=os.path.join(pathway_part,to_add)


    ph=ph+1
    for i, chunk in enumerate(chunks):
        to_add2="H"+"F"+str(ph+i)+".wav"
        pl=os.path.join(pathway_part,to_add2)
        chunk_name = pl.format(i)
        if(len(chunk)==5000):  
            print("exporting", chunk_name)
            chunk.export(chunk_name, format="wav")
            annotations.append([pl, objclass])
            counter+=1
        else:
            i=i-1
    ph=ph+i

    
    
    

    
    

for j in range(0,100):
    to_add="Sad Flute (1)/"+"S"+str(j+1)+".wav"

    pathway_part= ""
    pathway=os.path.join(pathway_part,to_add)

    myaudio = AudioSegment.from_file(pathway , "wav") 
    chunk_length_ms = 5000 # pydub calculates in millisec
    chunks = make_chunks(myaudio, chunk_length_ms) #Make chunks of five secs

    pathway_part= "splice_try"
    #pathway=os.path.join(pathway_part,to_add)


    ph=ph+1
    for i, chunk in enumerate(chunks):
        to_add2="S"+"F"+str(ph+i)+".wav"
        pl=os.path.join(pathway_part,to_add2)
        chunk_name = pl.format(i)
        if(len(chunk)==5000):  
            print("exporting", chunk_name)
            chunk.export(chunk_name, format="wav")
            annotations.append([pl, objclass])
            counter+=1
        else:
            i=i-1
    ph=ph+i
   
   
    

   
for j in range(100,200):
    to_add="Sad Flute (2)/"+"S"+str(j+1)+".wav"

    pathway_part= ""
    pathway=os.path.join(pathway_part,to_add)

    myaudio = AudioSegment.from_file(pathway , "wav") 
    chunk_length_ms = 5000 # pydub calculates in millisec
    chunks = make_chunks(myaudio, chunk_length_ms) #Make chunks of five secs

    pathway_part= "splice_try"
    #pathway=os.path.join(pathway_part,to_add)

    ph=ph+1
    for i, chunk in enumerate(chunks):
        to_add2="S"+"F"+str(ph+i)+".wav"
        pl=os.path.join(pathway_part,to_add2)
        
        chunk_name = pl.format(i)
        if(len(chunk)==5000):  
            print("exporting", chunk_name)
            chunk.export(chunk_name, format="wav")
            annotations.append([pl, objclass])
            counter+=1
        else:
            i=i-1
    ph=ph+i
# Out:
# exporting splice_try/AF0.wav
# exporting splice_try/AF1.wav
# exporting splice_try/AF2.wav
# exporting splice_try/AF3.wav
# exporting splice_try/AF4.wav
# exporting splice_try/AF5.wav
# exporting splice_try/AF6.wav
# exporting splice_try/AF7.wav
# exporting splice_try/AF8.wav
# exporting splice_try/AF9.wav
# exporting splice_try/AF10.wav
# exporting splice_try/AF11.wav
# exporting splice_try/AF12.wav
# exporting splice_try/AF13.wav
# exporting splice_try/AF14.wav
# exporting splice_try/AF15.wav
# exporting splice_try/AF16.wav
# exporting splice_try/AF17.wav
# exporting splice_try/AF18.wav
# exporting splice_try/AF19.wav
# exporting splice_try/AF20.wav
# exporting splice_try/AF21.wav
# exporting splice_try/AF22.wav
# exporting splice_try/AF23.wav
# exporting splice_try/AF24.wav
# exporting splice_try/AF25.wav
# exporting splice_try/AF26.wav
# exporting splice_try/AF27.wav
# exporting splice_try/AF28.wav
# exporting splice_try/AF29.wav
# exporting splice_try/AF30.wav
# ...

# %%
counter
# Out:
# 4589

# %%
len(annotations)
# Out:
# 4589

# %%
#start Sarod

# %%
ph
# Out:
# 4588

# %%
objclass=1
for j in range(0,100):
    to_add="Anxiety Sarod (1)/"+"A"+str(j+1)+".wav"

    pathway_part= ""
    pathway=os.path.join(pathway_part,to_add)

    myaudio = AudioSegment.from_file(pathway , "wav") 
    chunk_length_ms = 5000 # pydub calculates in millisec
    chunks = make_chunks(myaudio, chunk_length_ms) #Make chunks of five secs

    pathway_part= "splice_try"
    #pathway=os.path.join(pathway_part,to_add)


    ph=ph+1
    for i, chunk in enumerate(chunks):
        to_add2="A"+"S"+str(ph+i)+".wav"
        pl=os.path.join(pathway_part,to_add2)
        chunk_name = pl.format(i)
        if(len(chunk)==5000):  
            print("exporting", chunk_name)
            chunk.export(chunk_name, format="wav")
            annotations.append([pl, objclass])
        else:
            i=i-1
    ph=ph+i
    

    
for j in range(100,200):
    to_add="Anxiety Sarod (2)/"+"A"+str(j+1)+".wav"

    pathway_part= ""
    pathway=os.path.join(pathway_part,to_add)

    myaudio = AudioSegment.from_file(pathway , "wav") 
    chunk_length_ms = 5000 # pydub calculates in millisec
    chunks = make_chunks(myaudio, chunk_length_ms) #Make chunks of five secs

    pathway_part= "splice_try"
    #pathway=os.path.join(pathway_part,to_add)


    ph+=1
    for i, chunk in enumerate(chunks):
        to_add2="A"+"S"+str(ph+i)+".wav"
        pl=os.path.join(pathway_part,to_add2)
        chunk_name = pl.format(i)
        if(len(chunk)==5000):  
            print("exporting", chunk_name)
            chunk.export(chunk_name, format="wav")
            annotations.append([pl, objclass])
        else:
            i=i-1
    ph=ph+i
    

    
    
    
    
for j in range(300,400):
    to_add="Calm sarod (1)/"+"C"+str(j+1)+".wav"

    pathway_part= ""
    pathway=os.path.join(pathway_part,to_add)

    myaudio = AudioSegment.from_file(pathway , "wav") 
    chunk_length_ms = 5000 # pydub calculates in millisec
    chunks = make_chunks(myaudio, chunk_length_ms) #Make chunks of five secs

    pathway_part= "splice_try"
    #pathway=os.path.join(pathway_part,to_add)


    ph+=1
    for i, chunk in enumerate(chunks):
        to_add2="C"+"S"+str(ph+i)+".wav"
        pl=os.path.join(pathway_part,to_add2)
        chunk_name = pl.format(i)
        if(len(chunk)==5000):  
            print("exporting", chunk_name)
            chunk.export(chunk_name, format="wav")
            annotations.append([pl, objclass])
        else:
            i=i-1
    ph=ph+i
    

    
    
    

for j in range(200,300):
    to_add="Calm sarod (2)/"+"C"+str(j+1)+".wav"

    pathway_part= ""
    pathway=os.path.join(pathway_part,to_add)

    myaudio = AudioSegment.from_file(pathway , "wav") 
    chunk_length_ms = 5000 # pydub calculates in millisec
    chunks = make_chunks(myaudio, chunk_length_ms) #Make chunks of five secs

    pathway_part= "splice_try"
    #pathway=os.path.join(pathway_part,to_add)


    ph+=1
    for i, chunk in enumerate(chunks):
        to_add2="C"+"S"+str(ph+i)+".wav"
        pl=os.path.join(pathway_part,to_add2)
        chunk_name = pl.format(i)
        if(len(chunk)==5000):  
            print("exporting", chunk_name)
            chunk.export(chunk_name, format="wav")
            annotations.append([pl, objclass])
        else:
            i=i-1
    ph=ph+i
   
  
    
    
    

    
    
    

for j in range(100,200):
    to_add="Happy Sarod (2)/"+"H"+str(j+1)+".wav"

    pathway_part= ""
    pathway=os.path.join(pathway_part,to_add)

    myaudio = AudioSegment.from_file(pathway , "wav") 
    chunk_length_ms = 5000 # pydub calculates in millisec
    chunks = make_chunks(myaudio, chunk_length_ms) #Make chunks of five secs

    pathway_part= "splice_try"
    #pathway=os.path.join(pathway_part,to_add)


    ph+=1
    for i, chunk in enumerate(chunks):
        to_add2="H"+"S"+str(ph+i)+".wav"
        pl=os.path.join(pathway_part,to_add2)
        chunk_name = pl.format(i)
        if(len(chunk)==5000):  
            print("exporting", chunk_name)
            chunk.export(chunk_name, format="wav")
            annotations.append([pl, objclass])
        else:
            i=i-1
    ph=ph+i
    
 
    
    

    

for j in range(0,100):
    to_add="Sad Sarod (1)/"+"S"+str(j+1)+".wav"

    pathway_part= ""
    pathway=os.path.join(pathway_part,to_add)

    myaudio = AudioSegment.from_file(pathway , "wav") 
    chunk_length_ms = 5000 # pydub calculates in millisec
    chunks = make_chunks(myaudio, chunk_length_ms) #Make chunks of five secs

    pathway_part= "splice_try"
    #pathway=os.path.join(pathway_part,to_add)


    ph+=1
    for i, chunk in enumerate(chunks):
        to_add2="S"+"S"+str(ph+i)+".wav"
        pl=os.path.join(pathway_part,to_add2)
        chunk_name = pl.format(i)
        if(len(chunk)==5000):  
            print("exporting", chunk_name)
            chunk.export(chunk_name, format="wav")
            annotations.append([pl, objclass])
        else:
            i=i-1
    ph=ph+i
   
    
    

for j in range(100,200):
    to_add="Sad Sarod (2)/"+"S"+str(j+1)+".wav"

    pathway_part= ""
    pathway=os.path.join(pathway_part,to_add)

    myaudio = AudioSegment.from_file(pathway , "wav") 
    chunk_length_ms = 5000 # pydub calculates in millisec
    chunks = make_chunks(myaudio, chunk_length_ms) #Make chunks of five secs

    pathway_part= "splice_try"
    #pathway=os.path.join(pathway_part,to_add)


    ph+=1
    for i, chunk in enumerate(chunks):
        to_add2="S"+"S"+str(ph+i)+".wav"
        pl=os.path.join(pathway_part,to_add2)
        chunk_name = pl.format(i)
        if(len(chunk)==5000):  
            print("exporting", chunk_name)
            chunk.export(chunk_name, format="wav")
            annotations.append([pl, objclass])
        else:
            i=i-1
    ph=ph+i
# Out:
# exporting splice_try/AS4589.wav
# exporting splice_try/AS4590.wav
# exporting splice_try/AS4591.wav
# exporting splice_try/AS4592.wav
# exporting splice_try/AS4593.wav
# exporting splice_try/AS4594.wav
# exporting splice_try/AS4595.wav
# exporting splice_try/AS4596.wav
# exporting splice_try/AS4597.wav
# exporting splice_try/AS4598.wav
# exporting splice_try/AS4599.wav
# exporting splice_try/AS4600.wav
# exporting splice_try/AS4601.wav
# exporting splice_try/AS4602.wav
# exporting splice_try/AS4603.wav
# exporting splice_try/AS4604.wav
# exporting splice_try/AS4605.wav
# exporting splice_try/AS4606.wav
# exporting splice_try/AS4607.wav
# exporting splice_try/AS4608.wav
# exporting splice_try/AS4609.wav
# exporting splice_try/AS4610.wav
# exporting splice_try/AS4611.wav
# exporting splice_try/AS4612.wav
# exporting splice_try/AS4613.wav
# exporting splice_try/AS4614.wav
# exporting splice_try/AS4615.wav
# exporting splice_try/AS4616.wav
# exporting splice_try/AS4617.wav
# ...

# %%
len(annotations)
# Out:
# 8597

# %%
df = pd.DataFrame(annotations, columns=['slice_file_name', 'classID'])

# %%
df2=df

# %%
df_shuffled = df2.sample(frac=1).reset_index(drop=True)

# %%
df_shuffled
# Out:
#             slice_file_name  classID
# 0     splice_try/SS7653.wav        1
# 1     splice_try/AF1100.wav        0
# 2     splice_try/SF3799.wav        0
# 3     splice_try/SF4125.wav        0
# 4     splice_try/HF2683.wav        0
# ...                     ...      ...
# 8592  splice_try/SS8103.wav        1
# 8593  splice_try/CS6420.wav        1
# 8594   splice_try/AF892.wav        0
# 8595  splice_try/SF3487.wav        0
# 8596  splice_try/SS8523.wav        1
#
# [8597 rows x 2 columns]

# %%
df_shuffled.to_csv('annotations_sarod_flute.csv')
